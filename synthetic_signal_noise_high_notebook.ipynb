# %% [markdown]
# ### Forecasting in Aquaponics

# %% [markdown]
# Libraries and setup

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import os
import sys

os.environ['KMP_DUPLICATE_LIB_OK']='True'
os.environ["CUDA_VISIBLE_DEVICES"] = "2" 

#np.set_printoptions(threshold=sys.maxsize)

#mpl.rcParams['figure.figsize'] = (14, 8)
mpl.rcParams['axes.grid'] = True

np.random.seed(10)

# %% [markdown]
# ## Data adquisition

# %% [markdown]
# ### Syntetic signal generation

# %%
def get_signal():
    
    n_input = 30
    n_samples = int(1e4)

    frec_min = 0
    frec_max = int(1e3)

    phase_min = 0
    phase_max = int(1e3)

    frec_input = np.random.randint(frec_min, frec_max, size= (n_input))
    frec_input = frec_input.reshape(n_input, 1)
    
    phase_input = np.random.randint(phase_min, phase_max, size= (n_input))

    t = np.arange(n_samples)
    t = t.reshape(n_samples, 1)
    
    signal_input = np.sin(t * frec_input.T  + phase_input)
    signal_nl = np.sqrt(np.abs(signal_input))
    signal_output = signal_nl.sum(axis = 1).reshape(n_samples, 1) # Try something non-linear 
    
    signal_noise = 0.1 * np.max(signal_output) * np.random.randn(signal_output.size)
    signal_output = signal_output + signal_noise.reshape(n_samples, 1)
    
    signal = np.concatenate((signal_output, signal_input), axis = 1)
    
    df = pd.DataFrame(signal)
    
    return df

df_grouped = get_signal()
print(df_grouped.head())
# Out:
#           0         1         2         3         4         5         6   \
# 0  25.260170 -0.997801 -0.873297  0.795861  0.106077 -0.836689 -0.149818
# 1  14.931588 -0.506314 -0.988036 -0.860146 -0.629794 -0.521628 -0.958950
# 2  18.418073  0.544097 -0.683284  0.913044 -0.994808 -0.106107  0.412009
# 3  19.240329  0.993875 -0.088429 -0.953852 -0.774024  0.329849  0.846301
# 4  20.171824  0.346508  0.543971  0.982032 -0.097452  0.702279 -0.643400
#
#          7         8         9   ...        21        22        23        24  \
# 0 -0.558789  0.999520  0.573407  ...  0.529108  0.475497  0.945416 -0.245194
# 1  0.877590  0.498739 -0.750908  ...  0.751027  0.279329 -0.236574 -0.008761
# 2 -0.999756 -0.529057 -0.739323  ...  0.909335  0.070602 -0.689785  0.228170
# 3  0.897914 -0.997801  0.587551  ...  0.990624 -0.141299  0.981924  0.452133
# 4 -0.594884 -0.412173  0.869145  ...  0.988008 -0.346847 -0.371236  0.650402
#
#          25        26        27        28        29        30
# 0  0.253853  0.801117 -0.948282  0.999520 -0.670252  0.996462
# 1 -0.551376 -0.329934 -0.313257  0.176105  0.210840 -0.676861
# 2 -0.989345 -0.253882  0.951036 -0.948263  0.304753 -0.167177
# 3 -0.768332  0.751027  0.304897 -0.452106 -0.739140  0.881685
# 4 -0.035549 -0.991787 -0.953716  0.816673  0.976571 -0.913056
#
# [5 rows x 31 columns]

# %% [markdown]
# Organize data in columns

# %% [markdown]
# Data visualization

# %%
sample_sensor = 0

df_grouped[sample_sensor].plot()
plt.xticks(rotation=20)
plt.show()

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# ### Selecting target

# %%
label_target = {
0: 'Results'}

# %% [markdown]
# ### Denoising dataframe - FFT filter

# %% [markdown]
# Check sampling frecuency

# %%
sampling_time = df_grouped.index.to_series().diff().median()
print(sampling_time)
# Out:
# 1.0

# %% [markdown]
# Design sample filter

# %%
df_clean = df_grouped.copy()

# %% [markdown]
# ### Feature selection via correlation analysis

# %%
# corr_mat = np.abs(df_clean.corr(method='pearson'))
# sns.heatmap(corr_mat)
# plt.show()

# corr_thl = 0.10
# corr_label = np.zeros(df_grouped.shape[1])

# for i in label_target:
#     corr_label = corr_label | (corr_mat[i] > corr_thl)

# df_clean = df_clean.loc[:, corr_label]

# %% [markdown]
# Describe  dataset

# %%
# print(df_clean.describe().transpose())

# %% [markdown]
# ## Split dataset: train, validation and test

# %%
total_data = len(df_clean)

train_perc, val_perc, test_perc = 0.7, 0.2, 0.1

train_df    = df_clean[0:int(total_data*train_perc)]
val_df      = df_clean[int(total_data*train_perc):int(total_data*(train_perc + val_perc))]
test_df     = df_clean[int(total_data*(train_perc + val_perc)):total_data]

# %% [markdown]
# ## Data normalization

# %% [markdown]
# Min-max normalization

# %%
def f_normalize_minmax(df, full_df):
    norm_df = (df - full_df.min()) / (full_df.max() - full_df.min())
    return norm_df

def f_inv_normalize_minmax(norm_df, full_df):
    df = norm_df * (full_df.max() - full_df.min()) + full_df.min()
    return df

norm_train_df   = f_normalize_minmax(train_df, df_clean)
norm_val_df     = f_normalize_minmax(val_df, df_clean)
norm_test_df    = f_normalize_minmax(test_df, df_clean)

# %% [markdown]
# Show tails with box plot

# %%
# melt_train_df = norm_train_df.melt(var_name = 'Label', value_name = 'Normalized value')
# plt.figure()
# ax = sns.violinplot(x = 'Label', y = 'Normalized value', data = melt_train_df)
# plt.show()

# %% [markdown]
# Plot normalized data

# %%
norm_train_df[1].plot(x = 'DateTime', y = 'Value', kind = 'line')
plt.xticks(rotation=20)
plt.title('Normalized data')
plt.show()

# %% [markdown]
# ## Create input and target dataframe - Window generation

# %%
n_hour_data = 65 # 65 entries ~ 1 hour - There is a variable sampling frecuency
n_hours_in  = 1
n_hours_out = 1

input_width     = n_hour_data * n_hours_in 
label_width     = n_hour_data * n_hours_out 
offset_width    = 1 # 1 as default

def f_window_gen(df, label_target, input_width, label_width, offset_width):

    time_range = df.index
    data = []
    target = []

    data_time = []
    target_time = []

    for i in range(len(time_range) - (input_width + offset_width + label_width)):
        range_data = df.loc[time_range[i]:time_range[input_width + i]].values
        data.append(range_data)
        data_time.append(time_range[i:input_width + i])

        range_target = df[label_target].loc[time_range[input_width + offset_width + i: input_width + offset_width + label_width + i]].values
        target.append(range_target.flatten('F'))
        target_time.append(time_range[input_width + offset_width + i: input_width + offset_width + label_width + i])

    data = np.array(data)
    target = np.array(target)

    return data, target, data_time, target_time

train_data, train_target, train_data_time, train_target_time = f_window_gen(norm_train_df, label_target, input_width, label_width, offset_width)
val_data, val_target, val_data_time, val_target_time = f_window_gen(norm_val_df, label_target, input_width, label_width, offset_width)
test_data, test_target, test_data_time, test_target_time = f_window_gen(norm_test_df, label_target, input_width, label_width, offset_width)

# %% [markdown]
# Plotting - Normalized values

# %%
def plot_results(label_target, label_time, label, results, label_width):
    n_label = np.int(len(label_target))

    sensor_tag = list(label_target.values())
    
    fig, ax = plt.subplots(n_label, sharex = 'all')
    
    for i in range(n_label):
        label_plot = label[((i) * label_width): ((i + 1)* label_width)]
        ax.plot(label_time, label_plot, color = 'blue', label = 'Real')
        
        results_plot = results[((i) * label_width): ((i + 1)* label_width)]
        ax.plot(label_time, results_plot, color = 'orange', label = 'Prediction')

        ax.set_ylabel(sensor_tag[i])

    lines, labels = fig.axes[-1].get_legend_handles_labels()
    fig.legend(lines, labels, loc = 'center right')
    plt.xticks(rotation=20)
    plt.xlabel('Day - Time')
    plt.show()

    pass

# %% [markdown]
# ### Plotting - History

# %%
def plot_history(history):

    acc = history.history['mean_absolute_error']
    val_acc = history.history['val_mean_absolute_error']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    # Get number of epochs
    epochs = range(len(acc))

    fig, ax = plt.subplots(2, sharex = 'all')

    # Plot training and validation accuracy per epoch
    ax[0].plot(epochs, acc, label = 'Training')
    ax[0].plot(epochs, val_acc, label = 'Validation')
    ax[0].title.set_text('Training and validation MAE')

    # Plot training and validation loss per epoch
    ax[1].plot(epochs, loss, label = 'Training')
    ax[1].plot(epochs, val_loss, label = 'Validation')
    ax[1].title.set_text('Training and validation loss')

    lines, labels = fig.axes[-1].get_legend_handles_labels()
    fig.legend(lines, labels, loc = 'center right')
    plt.xticks(rotation=20)
    plt.xlabel('epochs')
    plt.show()

# %% [markdown]
# ## Architecture and Deployment

# %% [markdown]
# Callbacks

# %%
def scheduler(epoch, lr):
    if epoch < 10:
        return lr
    else:
        return lr * 0.9

# %% [markdown]
# Training method

# %%
def compile_and_fit(model, train_data, train_target, val_data, val_target, 
                    test_data, test_target, max_epochs, batch_size, test_entry, label_width):

    # Add callbacks
    early_stop = tf.keras.callbacks.EarlyStopping(monitor = "val_loss", 
                                                  patience = 5)
    lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose = 0)
    callbacks = [early_stop, lr_scheduler]

    # Model compile
    model.compile(loss      = tf.losses.MeanSquaredError(),
                  optimizer = tf.optimizers.Adam(),
                  metrics   = [tf.metrics.MeanAbsoluteError()])

    # Model fit
    history = model.fit(train_data,
                        train_target,
                        batch_size = batch_size,
                        epochs  = max_epochs,
                        verbose = 1,
                        shuffle = False, 
                        validation_data = (val_data, val_target),
                        callbacks = callbacks)

    model.summary()
    
    # Model evaluate
    model.evaluate(test_data, test_target)

    # Test model
    test_data = np.reshape(test_data[test_entry], (1, test_data[0].shape[0], test_data[0].shape[1]))
    test_prediction = model.predict(test_data)
    
    test_prediction = np.squeeze(test_prediction)
    
    # Plot results
    plot_results(label_target, test_target_time[test_entry], test_target[test_entry], test_prediction, label_width)

    plot_history(history)

    return history, test_prediction

test_entry = np.random.randint(0, 100)

# %% [markdown]
# # Models

# %% [markdown]
# ## Linear model

# %%
def f_linear_model(label_target, label_width):
    model = tf.keras.Sequential([
            tf.keras.layers.Flatten(),
            
            tf.keras.layers.Dense(units = 1000, kernel_initializer='random_normal', bias_initializer='zeros'),
            tf.keras.layers.Dropout(0.2),
        
            tf.keras.layers.Dense(units = 700, kernel_initializer='random_normal', bias_initializer='zeros'),
            tf.keras.layers.Dropout(0.2),
        
            tf.keras.layers.Dense(units = len(label_target) * label_width, kernel_initializer='random_normal', bias_initializer='zeros')])
    return model

linear_model = f_linear_model(label_target, label_width)

# %%
max_epochs = 25
batch_size = 100

linear_history, linear_prediction = compile_and_fit(linear_model, train_data, train_target, val_data, val_target, 
                                                    test_data, test_target, max_epochs, batch_size, test_entry, label_width)
# Out:
# Train on 6869 samples, validate on 1869 samples
# Epoch 1/25
# 6869/6869 [==============================] - 1s 120us/sample - loss: 4.1788 - mean_absolute_error: 1.3822 - val_loss: 0.0999 - val_mean_absolute_error: 0.2532
# Epoch 2/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.8235 - mean_absolute_error: 0.7219 - val_loss: 0.0722 - val_mean_absolute_error: 0.2132
# Epoch 3/25
# 6869/6869 [==============================] - 0s 43us/sample - loss: 0.5218 - mean_absolute_error: 0.5743 - val_loss: 0.0506 - val_mean_absolute_error: 0.1785
# Epoch 4/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.3490 - mean_absolute_error: 0.4696 - val_loss: 0.0398 - val_mean_absolute_error: 0.1593
# Epoch 5/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.2458 - mean_absolute_error: 0.3941 - val_loss: 0.0371 - val_mean_absolute_error: 0.1530
# Epoch 6/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.1838 - mean_absolute_error: 0.3408 - val_loss: 0.0348 - val_mean_absolute_error: 0.1492
# Epoch 7/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.1436 - mean_absolute_error: 0.3012 - val_loss: 0.0274 - val_mean_absolute_error: 0.1324
# Epoch 8/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.1153 - mean_absolute_error: 0.2700 - val_loss: 0.0262 - val_mean_absolute_error: 0.1291
# Epoch 9/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.0957 - mean_absolute_error: 0.2461 - val_loss: 0.0274 - val_mean_absolute_error: 0.1326
# Epoch 10/25
# 6869/6869 [==============================] - 0s 41us/sample - loss: 0.0818 - mean_absolute_error: 0.2276 - val_loss: 0.0228 - val_mean_absolute_error: 0.1207
# Epoch 11/25
# 6869/6869 [==============================] - 0s 41us/sample - loss: 0.0696 - mean_absolute_error: 0.2098 - val_loss: 0.0240 - val_mean_absolute_error: 0.1242
# Epoch 12/25
# 6869/6869 [==============================] - 0s 43us/sample - loss: 0.0615 - mean_absolute_error: 0.1975 - val_loss: 0.0223 - val_mean_absolute_error: 0.1195
# Epoch 13/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.0562 - mean_absolute_error: 0.1885 - val_loss: 0.0204 - val_mean_absolute_error: 0.1144
# Epoch 14/25
# 6869/6869 [==============================] - 0s 43us/sample - loss: 0.0511 - mean_absolute_error: 0.1800 - val_loss: 0.0200 - val_mean_absolute_error: 0.1132
# Epoch 15/25
# 6869/6869 [==============================] - 0s 43us/sample - loss: 0.0476 - mean_absolute_error: 0.1737 - val_loss: 0.0198 - val_mean_absolute_error: 0.1126
# Epoch 16/25
# 6869/6869 [==============================] - 0s 43us/sample - loss: 0.0444 - mean_absolute_error: 0.1680 - val_loss: 0.0197 - val_mean_absolute_error: 0.1125
# Epoch 17/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.0421 - mean_absolute_error: 0.1634 - val_loss: 0.0190 - val_mean_absolute_error: 0.1103
# Epoch 18/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.0403 - mean_absolute_error: 0.1601 - val_loss: 0.0198 - val_mean_absolute_error: 0.1129
# Epoch 19/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.0384 - mean_absolute_error: 0.1561 - val_loss: 0.0187 - val_mean_absolute_error: 0.1096
# Epoch 20/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.0368 - mean_absolute_error: 0.1528 - val_loss: 0.0187 - val_mean_absolute_error: 0.1094
# Epoch 21/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.0358 - mean_absolute_error: 0.1507 - val_loss: 0.0185 - val_mean_absolute_error: 0.1090
# Epoch 22/25
# 6869/6869 [==============================] - 0s 41us/sample - loss: 0.0347 - mean_absolute_error: 0.1484 - val_loss: 0.0185 - val_mean_absolute_error: 0.1089
# Epoch 23/25
# 6869/6869 [==============================] - 0s 41us/sample - loss: 0.0339 - mean_absolute_error: 0.1467 - val_loss: 0.0184 - val_mean_absolute_error: 0.1086
# Epoch 24/25
# 6869/6869 [==============================] - 0s 41us/sample - loss: 0.0332 - mean_absolute_error: 0.1453 - val_loss: 0.0183 - val_mean_absolute_error: 0.1085
# Epoch 25/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.0325 - mean_absolute_error: 0.1437 - val_loss: 0.0189 - val_mean_absolute_error: 0.1100
# Model: "sequential_17"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_6 (Flatten)          multiple                  0
# _________________________________________________________________
# dense_29 (Dense)             multiple                  2047000
# _________________________________________________________________
# dropout_12 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_30 (Dense)             multiple                  700700
# _________________________________________________________________
# dropout_13 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_31 (Dense)             multiple                  45565
# =================================================================
# Total params: 2,793,265
# Trainable params: 2,793,265
# Non-trainable params: 0
# _________________________________________________________________
# 869/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %% [markdown]
# ## MLP model

# %%
def f_mlp_model(label_target, label_width):
    model = tf.keras.Sequential([
            tf.keras.layers.Flatten(),
        
            tf.keras.layers.Dense(units = 1000, activation = 'tanh', kernel_initializer='random_normal', bias_initializer='zeros'),
            tf.keras.layers.Dropout(0.2),
        
            tf.keras.layers.Dense(units = 700, activation = 'tanh', kernel_initializer='random_normal', bias_initializer='zeros'),
            tf.keras.layers.Dropout(0.2),
        
        
        
            tf.keras.layers.Dense(units = len(label_target) * label_width)])
    return model
    
mlp_model = f_mlp_model(label_target, label_width)

# %%
max_epochs = 30
batch_size = 25
mlp_history, mlp_prediction = compile_and_fit(mlp_model, train_data, train_target, val_data, val_target, 
                                              test_data, test_target, max_epochs, batch_size, test_entry, label_width)
# Out:
# Train on 6869 samples, validate on 1869 samples
# Epoch 1/30
# 6869/6869 [==============================] - 1s 211us/sample - loss: 0.4160 - mean_absolute_error: 0.5081 - val_loss: 0.0416 - val_mean_absolute_error: 0.1653
# Epoch 2/30
# 6869/6869 [==============================] - 1s 148us/sample - loss: 0.2221 - mean_absolute_error: 0.3738 - val_loss: 0.0313 - val_mean_absolute_error: 0.1421
# Epoch 3/30
# 6869/6869 [==============================] - 1s 145us/sample - loss: 0.1198 - mean_absolute_error: 0.2744 - val_loss: 0.0257 - val_mean_absolute_error: 0.1283
# Epoch 4/30
# 6869/6869 [==============================] - 1s 144us/sample - loss: 0.0636 - mean_absolute_error: 0.1998 - val_loss: 0.0239 - val_mean_absolute_error: 0.1236
# Epoch 5/30
# 6869/6869 [==============================] - 1s 141us/sample - loss: 0.0372 - mean_absolute_error: 0.1531 - val_loss: 0.0204 - val_mean_absolute_error: 0.1145
# Epoch 6/30
# 6869/6869 [==============================] - 1s 146us/sample - loss: 0.0261 - mean_absolute_error: 0.1287 - val_loss: 0.0195 - val_mean_absolute_error: 0.1120
# Epoch 7/30
# 6869/6869 [==============================] - 1s 148us/sample - loss: 0.0216 - mean_absolute_error: 0.1174 - val_loss: 0.0203 - val_mean_absolute_error: 0.1140
# Epoch 8/30
# 6869/6869 [==============================] - 1s 146us/sample - loss: 0.0203 - mean_absolute_error: 0.1137 - val_loss: 0.0200 - val_mean_absolute_error: 0.1132
# Epoch 9/30
# 6869/6869 [==============================] - 1s 144us/sample - loss: 0.0202 - mean_absolute_error: 0.1134 - val_loss: 0.0191 - val_mean_absolute_error: 0.1109
# Epoch 10/30
# 6869/6869 [==============================] - 1s 140us/sample - loss: 0.0203 - mean_absolute_error: 0.1137 - val_loss: 0.0192 - val_mean_absolute_error: 0.1109
# Epoch 11/30
# 6869/6869 [==============================] - 1s 140us/sample - loss: 0.0202 - mean_absolute_error: 0.1136 - val_loss: 0.0197 - val_mean_absolute_error: 0.1124
# Epoch 12/30
# 6869/6869 [==============================] - 1s 144us/sample - loss: 0.0204 - mean_absolute_error: 0.1139 - val_loss: 0.0199 - val_mean_absolute_error: 0.1130
# Epoch 13/30
# 6869/6869 [==============================] - 1s 139us/sample - loss: 0.0202 - mean_absolute_error: 0.1136 - val_loss: 0.0199 - val_mean_absolute_error: 0.1130
# Epoch 14/30
# 6869/6869 [==============================] - 1s 146us/sample - loss: 0.0204 - mean_absolute_error: 0.1139 - val_loss: 0.0192 - val_mean_absolute_error: 0.1112
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_7 (Flatten)          multiple                  0
# _________________________________________________________________
# dense_32 (Dense)             multiple                  2047000
# _________________________________________________________________
# dropout_14 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_33 (Dense)             multiple                  700700
# _________________________________________________________________
# dropout_15 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_34 (Dense)             multiple                  45565
# =================================================================
# Total params: 2,793,265
# Trainable params: 2,793,265
# Non-trainable params: 0
# _________________________________________________________________
# 869/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %% [markdown]
# ## LSTM RNN model

# %%
def f_lstm_model(input_shape, output_shape):
    model = tf.keras.Sequential([
        
            tf.keras.layers.LSTM(units = 1000, input_shape = input_shape, kernel_initializer='random_normal', bias_initializer='zeros', dropout=0.2, return_sequences=True),
        
            tf.keras.layers.LSTM(units = 700, input_shape = input_shape, kernel_initializer='random_normal', bias_initializer='zeros', dropout=0.2, return_sequences=False),

            tf.keras.layers.Dense(output_shape)])
    return model

input_shape = train_data[0].shape
output_shape = train_target.shape[1]
lstm_model = f_lstm_model(input_shape, output_shape)

# %%
max_epochs = 30
batch_size = 50
lstm_history, lstm_prediction = compile_and_fit(lstm_model, train_data, train_target, val_data, val_target, 
                                                test_data, test_target, max_epochs, batch_size, test_entry, label_width)
# Out:
# Train on 6869 samples, validate on 1869 samples
# Epoch 1/30
# 6869/6869 [==============================] - 11s 2ms/sample - loss: 0.0256 - mean_absolute_error: 0.1185 - val_loss: 0.0183 - val_mean_absolute_error: 0.1086
# Epoch 2/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0180 - mean_absolute_error: 0.1072 - val_loss: 0.0183 - val_mean_absolute_error: 0.1087
# Epoch 3/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0179 - mean_absolute_error: 0.1069 - val_loss: 0.0183 - val_mean_absolute_error: 0.1086
# Epoch 4/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0178 - mean_absolute_error: 0.1067 - val_loss: 0.0183 - val_mean_absolute_error: 0.1085
# Epoch 5/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0178 - mean_absolute_error: 0.1065 - val_loss: 0.0183 - val_mean_absolute_error: 0.1085
# Epoch 6/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0177 - mean_absolute_error: 0.1064 - val_loss: 0.0182 - val_mean_absolute_error: 0.1084
# Epoch 7/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0177 - mean_absolute_error: 0.1063 - val_loss: 0.0182 - val_mean_absolute_error: 0.1084
# Epoch 8/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0177 - mean_absolute_error: 0.1063 - val_loss: 0.0182 - val_mean_absolute_error: 0.1084
# Epoch 9/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0177 - mean_absolute_error: 0.1062 - val_loss: 0.0182 - val_mean_absolute_error: 0.1084
# Epoch 10/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0177 - mean_absolute_error: 0.1061 - val_loss: 0.0182 - val_mean_absolute_error: 0.1084
# Epoch 11/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0176 - mean_absolute_error: 0.1061 - val_loss: 0.0182 - val_mean_absolute_error: 0.1084
# Epoch 12/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0176 - mean_absolute_error: 0.1061 - val_loss: 0.0182 - val_mean_absolute_error: 0.1083
# Epoch 13/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0176 - mean_absolute_error: 0.1061 - val_loss: 0.0182 - val_mean_absolute_error: 0.1083
# Epoch 14/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0176 - mean_absolute_error: 0.1060 - val_loss: 0.0182 - val_mean_absolute_error: 0.1082
# Epoch 15/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0176 - mean_absolute_error: 0.1060 - val_loss: 0.0182 - val_mean_absolute_error: 0.1082
# Epoch 16/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0175 - mean_absolute_error: 0.1059 - val_loss: 0.0182 - val_mean_absolute_error: 0.1081
# Epoch 17/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0175 - mean_absolute_error: 0.1058 - val_loss: 0.0181 - val_mean_absolute_error: 0.1081
# Epoch 18/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0175 - mean_absolute_error: 0.1058 - val_loss: 0.0181 - val_mean_absolute_error: 0.1080
# Epoch 19/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0175 - mean_absolute_error: 0.1057 - val_loss: 0.0181 - val_mean_absolute_error: 0.1079
# Epoch 20/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0174 - mean_absolute_error: 0.1056 - val_loss: 0.0181 - val_mean_absolute_error: 0.1079
# Epoch 21/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0174 - mean_absolute_error: 0.1055 - val_loss: 0.0181 - val_mean_absolute_error: 0.1078
# Epoch 22/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0174 - mean_absolute_error: 0.1054 - val_loss: 0.0181 - val_mean_absolute_error: 0.1078
# Epoch 23/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0173 - mean_absolute_error: 0.1053 - val_loss: 0.0181 - val_mean_absolute_error: 0.1078
# Epoch 24/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0173 - mean_absolute_error: 0.1052 - val_loss: 0.0180 - val_mean_absolute_error: 0.1078
# Epoch 25/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0173 - mean_absolute_error: 0.1052 - val_loss: 0.0180 - val_mean_absolute_error: 0.1077
# Epoch 26/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0173 - mean_absolute_error: 0.1051 - val_loss: 0.0180 - val_mean_absolute_error: 0.1077
# Epoch 27/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0172 - mean_absolute_error: 0.1050 - val_loss: 0.0180 - val_mean_absolute_error: 0.1077
# Epoch 28/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0172 - mean_absolute_error: 0.1050 - val_loss: 0.0180 - val_mean_absolute_error: 0.1076
# Epoch 29/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0172 - mean_absolute_error: 0.1049 - val_loss: 0.0180 - val_mean_absolute_error: 0.1076
# Epoch 30/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0172 - mean_absolute_error: 0.1048 - val_loss: 0.0180 - val_mean_absolute_error: 0.1076
# Model: "sequential_19"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 66, 1000)          4128000
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 700)               4762800
# _________________________________________________________________
# dense_35 (Dense)             (None, 65)                45565
# =================================================================
# Total params: 8,936,365
# Trainable params: 8,936,365
# Non-trainable params: 0
# _________________________________________________________________
# 869/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %% [markdown]
# ## GRU RNN model

# %%
def f_gru_model(input_shape, output_shape):
    model = tf.keras.Sequential([
            tf.keras.layers.GRU(units = 1000, input_shape = input_shape, kernel_initializer='random_normal', bias_initializer='zeros', dropout=0.2, return_sequences=True),
        
#             tf.keras.layers.GRU(units = 700, input_shape = input_shape, kernel_initializer='random_normal', bias_initializer='zeros', dropout=0.2, return_sequences=True),
        
            tf.keras.layers.GRU(units = 1000, input_shape = input_shape, kernel_initializer='random_normal', bias_initializer='zeros', dropout=0.2, return_sequences=False),
        
#             tf.keras.layers.GRU(units = 200, input_shape = input_shape, kernel_initializer='random_normal', bias_initializer='zeros', dropout=0.2, return_sequences=False),

            tf.keras.layers.Dense(output_shape)])
    return model

input_shape = train_data[0].shape
output_shape = train_target.shape[1]
gru_model = f_gru_model(input_shape, output_shape)

# %%
max_epochs = 30
batch_size = 50
gru_history, gru_prediction = compile_and_fit(gru_model, train_data, train_target, val_data, val_target, 
                                              test_data, test_target, max_epochs, batch_size, test_entry, label_width)
# Out:
# Train on 6869 samples, validate on 1869 samples
# Epoch 1/30
# 6869/6869 [==============================] - 11s 2ms/sample - loss: 0.0333 - mean_absolute_error: 0.1318 - val_loss: 0.0189 - val_mean_absolute_error: 0.1103
# Epoch 2/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0189 - mean_absolute_error: 0.1099 - val_loss: 0.0188 - val_mean_absolute_error: 0.1100
# Epoch 3/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0185 - mean_absolute_error: 0.1086 - val_loss: 0.0188 - val_mean_absolute_error: 0.1101
# Epoch 4/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0183 - mean_absolute_error: 0.1081 - val_loss: 0.0187 - val_mean_absolute_error: 0.1098
# Epoch 5/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0182 - mean_absolute_error: 0.1079 - val_loss: 0.0187 - val_mean_absolute_error: 0.1096
# Epoch 6/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0182 - mean_absolute_error: 0.1078 - val_loss: 0.0188 - val_mean_absolute_error: 0.1100
# Epoch 7/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0181 - mean_absolute_error: 0.1075 - val_loss: 0.0188 - val_mean_absolute_error: 0.1100
# Epoch 8/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0181 - mean_absolute_error: 0.1075 - val_loss: 0.0189 - val_mean_absolute_error: 0.1101
# Epoch 9/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0180 - mean_absolute_error: 0.1072 - val_loss: 0.0190 - val_mean_absolute_error: 0.1106
# Epoch 10/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0181 - mean_absolute_error: 0.1076 - val_loss: 0.0197 - val_mean_absolute_error: 0.1124
# Model: "sequential_20"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_18 (GRU)                 (None, 66, 1000)          3099000
# _________________________________________________________________
# gru_19 (GRU)                 (None, 1000)              6006000
# _________________________________________________________________
# dense_36 (Dense)             (None, 65)                65065
# =================================================================
# Total params: 9,170,065
# Trainable params: 9,170,065
# Non-trainable params: 0
# _________________________________________________________________
# 869/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
