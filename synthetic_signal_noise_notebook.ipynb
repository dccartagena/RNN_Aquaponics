# %% [markdown]
# ### Forecasting in Aquaponics

# %% [markdown]
# Libraries and setup

# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import os
import sys

os.environ['KMP_DUPLICATE_LIB_OK']='True'
os.environ["CUDA_VISIBLE_DEVICES"] = "1" 

#np.set_printoptions(threshold=sys.maxsize)

#mpl.rcParams['figure.figsize'] = (14, 8)
mpl.rcParams['axes.grid'] = True

np.random.seed(10)

# %% [markdown]
# ## Data adquisition

# %% [markdown]
# ### Syntetic signal generation

# %%
def get_signal():
    
    n_input = 30
    n_samples = int(1e4)

    frec_min = 0
    frec_max = int(1e3)

    phase_min = 0
    phase_max = int(1e3)

    frec_input = np.random.randint(frec_min, frec_max, size= (n_input))
    frec_input = frec_input.reshape(n_input, 1)
    
    phase_input = np.random.randint(phase_min, phase_max, size= (n_input))

    t = np.arange(n_samples)
    t = t.reshape(n_samples, 1)
    
    signal_input = np.sin(t * frec_input.T  + phase_input)
    signal_nl = np.sqrt(np.abs(signal_input))
    signal_output = signal_nl.sum(axis = 1).reshape(n_samples, 1) # Try something non-linear 
    
    signal_noise = 0.01 * np.max(signal_output) * np.random.randn(signal_output.size)
    signal_output = signal_output + signal_noise.reshape(n_samples, 1)
    
    signal = np.concatenate((signal_output, signal_input), axis = 1)
    
    df = pd.DataFrame(signal)
    
    return df

df_grouped = get_signal()
print(df_grouped.head())
# Out:
#           0         1         2         3         4         5         6   \
# 0  23.637192 -0.997801 -0.873297  0.795861  0.106077 -0.836689 -0.149818
# 1  19.505918 -0.506314 -0.988036 -0.860146 -0.629794 -0.521628 -0.958950
# 2  20.671009  0.544097 -0.683284  0.913044 -0.994808 -0.106107  0.412009
# 3  23.413031  0.993875 -0.088429 -0.953852 -0.774024  0.329849  0.846301
# 4  22.612382  0.346508  0.543971  0.982032 -0.097452  0.702279 -0.643400
#
#          7         8         9   ...        21        22        23        24  \
# 0 -0.558789  0.999520  0.573407  ...  0.529108  0.475497  0.945416 -0.245194
# 1  0.877590  0.498739 -0.750908  ...  0.751027  0.279329 -0.236574 -0.008761
# 2 -0.999756 -0.529057 -0.739323  ...  0.909335  0.070602 -0.689785  0.228170
# 3  0.897914 -0.997801  0.587551  ...  0.990624 -0.141299  0.981924  0.452133
# 4 -0.594884 -0.412173  0.869145  ...  0.988008 -0.346847 -0.371236  0.650402
#
#          25        26        27        28        29        30
# 0  0.253853  0.801117 -0.948282  0.999520 -0.670252  0.996462
# 1 -0.551376 -0.329934 -0.313257  0.176105  0.210840 -0.676861
# 2 -0.989345 -0.253882  0.951036 -0.948263  0.304753 -0.167177
# 3 -0.768332  0.751027  0.304897 -0.452106 -0.739140  0.881685
# 4 -0.035549 -0.991787 -0.953716  0.816673  0.976571 -0.913056
#
# [5 rows x 31 columns]

# %% [markdown]
# Organize data in columns

# %% [markdown]
# Data visualization

# %%
sample_sensor = 0

df_grouped[sample_sensor].plot()
plt.xticks(rotation=20)
plt.show()

# %% [markdown]
# ## Data Pre-processing

# %% [markdown]
# ### Selecting target

# %%
label_target = {
0: 'Results'}

# %% [markdown]
# ### Denoising dataframe - FFT filter

# %% [markdown]
# Check sampling frecuency

# %%
sampling_time = df_grouped.index.to_series().diff().median()
print(sampling_time)
# Out:
# 1.0

# %% [markdown]
# Design sample filter

# %%
df_clean = df_grouped.copy()

# %% [markdown]
# ### Feature selection via correlation analysis

# %%
# corr_mat = np.abs(df_clean.corr(method='pearson'))
# sns.heatmap(corr_mat)
# plt.show()

# corr_thl = 0.10
# corr_label = np.zeros(df_grouped.shape[1])

# for i in label_target:
#     corr_label = corr_label | (corr_mat[i] > corr_thl)

# df_clean = df_clean.loc[:, corr_label]

# %% [markdown]
# Describe  dataset

# %%
# print(df_clean.describe().transpose())

# %% [markdown]
# ## Split dataset: train, validation and test

# %%
total_data = len(df_clean)

train_perc, val_perc, test_perc = 0.7, 0.2, 0.1

train_df    = df_clean[0:int(total_data*train_perc)]
val_df      = df_clean[int(total_data*train_perc):int(total_data*(train_perc + val_perc))]
test_df     = df_clean[int(total_data*(train_perc + val_perc)):total_data]

# %% [markdown]
# ## Data normalization

# %% [markdown]
# Min-max normalization

# %%
def f_normalize_minmax(df, full_df):
    norm_df = (df - full_df.min()) / (full_df.max() - full_df.min())
    return norm_df

def f_inv_normalize_minmax(norm_df, full_df):
    df = norm_df * (full_df.max() - full_df.min()) + full_df.min()
    return df

norm_train_df   = f_normalize_minmax(train_df, df_clean)
norm_val_df     = f_normalize_minmax(val_df, df_clean)
norm_test_df    = f_normalize_minmax(test_df, df_clean)

# %% [markdown]
# Show tails with box plot

# %%
# melt_train_df = norm_train_df.melt(var_name = 'Label', value_name = 'Normalized value')
# plt.figure()
# ax = sns.violinplot(x = 'Label', y = 'Normalized value', data = melt_train_df)
# plt.show()

# %% [markdown]
# Plot normalized data

# %%
norm_train_df[1].plot(x = 'DateTime', y = 'Value', kind = 'line')
plt.xticks(rotation=20)
plt.title('Normalized data')
plt.show()

# %% [markdown]
# ## Create input and target dataframe - Window generation

# %%
n_hour_data = 65 # 65 entries ~ 1 hour - There is a variable sampling frecuency
n_hours_in  = 1
n_hours_out = 1

input_width     = n_hour_data * n_hours_in 
label_width     = n_hour_data * n_hours_out 
offset_width    = 1 # 1 as default

def f_window_gen(df, label_target, input_width, label_width, offset_width):

    time_range = df.index
    data = []
    target = []

    data_time = []
    target_time = []

    for i in range(len(time_range) - (input_width + offset_width + label_width)):
        range_data = df.loc[time_range[i]:time_range[input_width + i]].values
        data.append(range_data)
        data_time.append(time_range[i:input_width + i])

        range_target = df[label_target].loc[time_range[input_width + offset_width + i: input_width + offset_width + label_width + i]].values
        target.append(range_target.flatten('F'))
        target_time.append(time_range[input_width + offset_width + i: input_width + offset_width + label_width + i])

    data = np.array(data)
    target = np.array(target)

    return data, target, data_time, target_time

train_data, train_target, train_data_time, train_target_time = f_window_gen(norm_train_df, label_target, input_width, label_width, offset_width)
val_data, val_target, val_data_time, val_target_time = f_window_gen(norm_val_df, label_target, input_width, label_width, offset_width)
test_data, test_target, test_data_time, test_target_time = f_window_gen(norm_test_df, label_target, input_width, label_width, offset_width)

# %% [markdown]
# Plotting - Normalized values

# %%
def plot_results(label_target, label_time, label, results, label_width):
    n_label = np.int(len(label_target))

    sensor_tag = list(label_target.values())
    
    fig, ax = plt.subplots(n_label, sharex = 'all')
    
    for i in range(n_label):
        label_plot = label[((i) * label_width): ((i + 1)* label_width)]
        ax.plot(label_time, label_plot, color = 'blue', label = 'Real')
        
        results_plot = results[((i) * label_width): ((i + 1)* label_width)]
        ax.plot(label_time, results_plot, color = 'orange', label = 'Prediction')

        ax.set_ylabel(sensor_tag[i])

    lines, labels = fig.axes[-1].get_legend_handles_labels()
    fig.legend(lines, labels, loc = 'center right')
    plt.xticks(rotation=20)
    plt.xlabel('Day - Time')
    plt.show()

    pass

# %% [markdown]
# ### Plotting - History

# %%
def plot_history(history):

    acc = history.history['mean_absolute_error']
    val_acc = history.history['val_mean_absolute_error']

    loss = history.history['loss']
    val_loss = history.history['val_loss']

    # Get number of epochs
    epochs = range(len(acc))

    fig, ax = plt.subplots(2, sharex = 'all')

    # Plot training and validation accuracy per epoch
    ax[0].plot(epochs, acc, label = 'Training')
    ax[0].plot(epochs, val_acc, label = 'Validation')
    ax[0].title.set_text('Training and validation MAE')

    # Plot training and validation loss per epoch
    ax[1].plot(epochs, loss, label = 'Training')
    ax[1].plot(epochs, val_loss, label = 'Validation')
    ax[1].title.set_text('Training and validation loss')

    lines, labels = fig.axes[-1].get_legend_handles_labels()
    fig.legend(lines, labels, loc = 'center right')
    plt.xticks(rotation=20)
    plt.xlabel('epochs')
    plt.show()

# %% [markdown]
# ## Architecture and Deployment

# %% [markdown]
# Callbacks

# %%
def scheduler(epoch, lr):
    if epoch < 5:
        return lr
    else:
        return lr * 0.9

# %% [markdown]
# Training method

# %%
def compile_and_fit(model, train_data, train_target, val_data, val_target, 
                    test_data, test_target, max_epochs, batch_size, test_entry, label_width):

    # Add callbacks
    early_stop = tf.keras.callbacks.EarlyStopping(monitor = "val_loss", 
                                                  patience = 5)
    lr_scheduler = tf.keras.callbacks.LearningRateScheduler(scheduler, verbose = 0)
    callbacks = [early_stop, lr_scheduler]

    # Model compile
    model.compile(loss      = tf.losses.MeanSquaredError(),
                  optimizer = tf.optimizers.Adam(),
                  metrics   = [tf.metrics.MeanAbsoluteError()])

    # Model fit
    history = model.fit(train_data,
                        train_target,
                        batch_size = batch_size,
                        epochs  = max_epochs,
                        verbose = 1,
                        shuffle = False, 
                        validation_data = (val_data, val_target),
                        callbacks = callbacks)

    model.summary()
    
    # Model evaluate
    model.evaluate(test_data, test_target)

    # Test model
    test_data = np.reshape(test_data[test_entry], (1, test_data[0].shape[0], test_data[0].shape[1]))
    test_prediction = model.predict(test_data)
    
    test_prediction = np.squeeze(test_prediction)
    
    # Plot results
    plot_results(label_target, test_target_time[test_entry], test_target[test_entry], test_prediction, label_width)

    plot_history(history)

    return history, test_prediction

test_entry = np.random.randint(0, 100)

# %% [markdown]
# # Models

# %% [markdown]
# ## Linear model

# %%
def f_linear_model(label_target, label_width):
    model = tf.keras.Sequential([
            tf.keras.layers.Flatten(),
            
            tf.keras.layers.Dense(units = 1000, kernel_initializer='random_normal', bias_initializer='zeros'),
            tf.keras.layers.Dropout(0.2),
        
            tf.keras.layers.Dense(units = len(label_target) * label_width, kernel_initializer='random_normal', bias_initializer='zeros')])
    return model

linear_model = f_linear_model(label_target, label_width)

# %%
max_epochs = 25
batch_size = 100

linear_history, linear_prediction = compile_and_fit(linear_model, train_data, train_target, val_data, val_target, 
                                                    test_data, test_target, max_epochs, batch_size, test_entry, label_width)
# Out:
# Train on 6869 samples, validate on 1869 samples
# Epoch 1/25
# 6869/6869 [==============================] - 1s 139us/sample - loss: 1.4773 - mean_absolute_error: 0.8116 - val_loss: 0.0628 - val_mean_absolute_error: 0.2004
# Epoch 2/25
# 6869/6869 [==============================] - 0s 41us/sample - loss: 0.3375 - mean_absolute_error: 0.4628 - val_loss: 0.0645 - val_mean_absolute_error: 0.2038
# Epoch 3/25
# 6869/6869 [==============================] - 0s 43us/sample - loss: 0.2705 - mean_absolute_error: 0.4144 - val_loss: 0.0646 - val_mean_absolute_error: 0.2026
# Epoch 4/25
# 6869/6869 [==============================] - 0s 41us/sample - loss: 0.2138 - mean_absolute_error: 0.3678 - val_loss: 0.0622 - val_mean_absolute_error: 0.1981
# Epoch 5/25
# 6869/6869 [==============================] - 0s 39us/sample - loss: 0.1662 - mean_absolute_error: 0.3244 - val_loss: 0.0478 - val_mean_absolute_error: 0.1749
# Epoch 6/25
# 6869/6869 [==============================] - 0s 41us/sample - loss: 0.1286 - mean_absolute_error: 0.2852 - val_loss: 0.0393 - val_mean_absolute_error: 0.1594
# Epoch 7/25
# 6869/6869 [==============================] - 0s 40us/sample - loss: 0.1004 - mean_absolute_error: 0.2518 - val_loss: 0.0363 - val_mean_absolute_error: 0.1530
# Epoch 8/25
# 6869/6869 [==============================] - 0s 39us/sample - loss: 0.0829 - mean_absolute_error: 0.2286 - val_loss: 0.0274 - val_mean_absolute_error: 0.1331
# Epoch 9/25
# 6869/6869 [==============================] - 0s 39us/sample - loss: 0.0693 - mean_absolute_error: 0.2091 - val_loss: 0.0254 - val_mean_absolute_error: 0.1279
# Epoch 10/25
# 6869/6869 [==============================] - 0s 39us/sample - loss: 0.0589 - mean_absolute_error: 0.1928 - val_loss: 0.0247 - val_mean_absolute_error: 0.1268
# Epoch 11/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.0520 - mean_absolute_error: 0.1811 - val_loss: 0.0201 - val_mean_absolute_error: 0.1139
# Epoch 12/25
# 6869/6869 [==============================] - 0s 41us/sample - loss: 0.0455 - mean_absolute_error: 0.1693 - val_loss: 0.0205 - val_mean_absolute_error: 0.1147
# Epoch 13/25
# 6869/6869 [==============================] - 0s 39us/sample - loss: 0.0411 - mean_absolute_error: 0.1611 - val_loss: 0.0170 - val_mean_absolute_error: 0.1045
# Epoch 14/25
# 6869/6869 [==============================] - 0s 38us/sample - loss: 0.0373 - mean_absolute_error: 0.1535 - val_loss: 0.0172 - val_mean_absolute_error: 0.1055
# Epoch 15/25
# 6869/6869 [==============================] - 0s 41us/sample - loss: 0.0346 - mean_absolute_error: 0.1480 - val_loss: 0.0164 - val_mean_absolute_error: 0.1028
# Epoch 16/25
# 6869/6869 [==============================] - 0s 39us/sample - loss: 0.0324 - mean_absolute_error: 0.1430 - val_loss: 0.0153 - val_mean_absolute_error: 0.0988
# Epoch 17/25
# 6869/6869 [==============================] - 0s 40us/sample - loss: 0.0300 - mean_absolute_error: 0.1376 - val_loss: 0.0149 - val_mean_absolute_error: 0.0980
# Epoch 18/25
# 6869/6869 [==============================] - 0s 41us/sample - loss: 0.0286 - mean_absolute_error: 0.1344 - val_loss: 0.0145 - val_mean_absolute_error: 0.0965
# Epoch 19/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.0271 - mean_absolute_error: 0.1308 - val_loss: 0.0144 - val_mean_absolute_error: 0.0963
# Epoch 20/25
# 6869/6869 [==============================] - 0s 42us/sample - loss: 0.0260 - mean_absolute_error: 0.1280 - val_loss: 0.0140 - val_mean_absolute_error: 0.0945
# Epoch 21/25
# 6869/6869 [==============================] - 0s 41us/sample - loss: 0.0249 - mean_absolute_error: 0.1254 - val_loss: 0.0139 - val_mean_absolute_error: 0.0944
# Epoch 22/25
# 6869/6869 [==============================] - 0s 39us/sample - loss: 0.0241 - mean_absolute_error: 0.1234 - val_loss: 0.0140 - val_mean_absolute_error: 0.0949
# Epoch 23/25
# 6869/6869 [==============================] - 0s 40us/sample - loss: 0.0232 - mean_absolute_error: 0.1211 - val_loss: 0.0135 - val_mean_absolute_error: 0.0932
# Epoch 24/25
# 6869/6869 [==============================] - 0s 41us/sample - loss: 0.0226 - mean_absolute_error: 0.1197 - val_loss: 0.0131 - val_mean_absolute_error: 0.0918
# Epoch 25/25
# 6869/6869 [==============================] - 0s 39us/sample - loss: 0.0219 - mean_absolute_error: 0.1177 - val_loss: 0.0133 - val_mean_absolute_error: 0.0923
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_2 (Flatten)          multiple                  0
# _________________________________________________________________
# dense_8 (Dense)              multiple                  2047000
# _________________________________________________________________
# dropout_4 (Dropout)          multiple                  0
# _________________________________________________________________
# dense_9 (Dense)              multiple                  65065
# =================================================================
# Total params: 2,112,065
# Trainable params: 2,112,065
# Non-trainable params: 0
# _________________________________________________________________
# 869/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %% [markdown]
# ## MLP model

# %%
def f_mlp_model(label_target, label_width):
    model = tf.keras.Sequential([
            tf.keras.layers.Flatten(),
        
            tf.keras.layers.Dense(units = 500, activation = 'tanh', kernel_initializer='random_normal', bias_initializer='zeros'),
            tf.keras.layers.Dropout(0.2),
        
        
            tf.keras.layers.Dense(units = len(label_target) * label_width)])
    return model
    
mlp_model = f_mlp_model(label_target, label_width)

# %%
max_epochs = 30
batch_size = 25
mlp_history, mlp_prediction = compile_and_fit(mlp_model, train_data, train_target, val_data, val_target, 
                                              test_data, test_target, max_epochs, batch_size, test_entry, label_width)
# Out:
# Train on 6869 samples, validate on 1869 samples
# Epoch 1/30
# 6869/6869 [==============================] - 2s 224us/sample - loss: 0.3791 - mean_absolute_error: 0.4855 - val_loss: 0.0633 - val_mean_absolute_error: 0.2007
# Epoch 2/30
# 6869/6869 [==============================] - 1s 137us/sample - loss: 0.1779 - mean_absolute_error: 0.3342 - val_loss: 0.0386 - val_mean_absolute_error: 0.1568
# Epoch 3/30
# 6869/6869 [==============================] - 1s 129us/sample - loss: 0.0856 - mean_absolute_error: 0.2317 - val_loss: 0.0309 - val_mean_absolute_error: 0.1409
# Epoch 4/30
# 6869/6869 [==============================] - 1s 130us/sample - loss: 0.0455 - mean_absolute_error: 0.1692 - val_loss: 0.0227 - val_mean_absolute_error: 0.1210
# Epoch 5/30
# 6869/6869 [==============================] - 1s 139us/sample - loss: 0.0283 - mean_absolute_error: 0.1337 - val_loss: 0.0190 - val_mean_absolute_error: 0.1104
# Epoch 6/30
# 6869/6869 [==============================] - 1s 137us/sample - loss: 0.0214 - mean_absolute_error: 0.1163 - val_loss: 0.0166 - val_mean_absolute_error: 0.1033
# Epoch 7/30
# 6869/6869 [==============================] - 1s 134us/sample - loss: 0.0177 - mean_absolute_error: 0.1059 - val_loss: 0.0164 - val_mean_absolute_error: 0.1030
# Epoch 8/30
# 6869/6869 [==============================] - 1s 135us/sample - loss: 0.0163 - mean_absolute_error: 0.1018 - val_loss: 0.0151 - val_mean_absolute_error: 0.0988
# Epoch 9/30
# 6869/6869 [==============================] - 1s 133us/sample - loss: 0.0152 - mean_absolute_error: 0.0983 - val_loss: 0.0139 - val_mean_absolute_error: 0.0947
# Epoch 10/30
# 6869/6869 [==============================] - 1s 137us/sample - loss: 0.0144 - mean_absolute_error: 0.0954 - val_loss: 0.0134 - val_mean_absolute_error: 0.0928
# Epoch 11/30
# 6869/6869 [==============================] - 1s 136us/sample - loss: 0.0138 - mean_absolute_error: 0.0937 - val_loss: 0.0121 - val_mean_absolute_error: 0.0884
# Epoch 12/30
# 6869/6869 [==============================] - 1s 142us/sample - loss: 0.0132 - mean_absolute_error: 0.0914 - val_loss: 0.0119 - val_mean_absolute_error: 0.0877
# Epoch 13/30
# 6869/6869 [==============================] - 1s 138us/sample - loss: 0.0129 - mean_absolute_error: 0.0906 - val_loss: 0.0116 - val_mean_absolute_error: 0.0861
# Epoch 14/30
# 6869/6869 [==============================] - 1s 134us/sample - loss: 0.0124 - mean_absolute_error: 0.0886 - val_loss: 0.0112 - val_mean_absolute_error: 0.0846
# Epoch 15/30
# 6869/6869 [==============================] - 1s 130us/sample - loss: 0.0121 - mean_absolute_error: 0.0875 - val_loss: 0.0112 - val_mean_absolute_error: 0.0849
# Epoch 16/30
# 6869/6869 [==============================] - 1s 140us/sample - loss: 0.0116 - mean_absolute_error: 0.0859 - val_loss: 0.0105 - val_mean_absolute_error: 0.0822
# Epoch 17/30
# 6869/6869 [==============================] - 1s 135us/sample - loss: 0.0114 - mean_absolute_error: 0.0851 - val_loss: 0.0100 - val_mean_absolute_error: 0.0800
# Epoch 18/30
# 6869/6869 [==============================] - 1s 130us/sample - loss: 0.0111 - mean_absolute_error: 0.0840 - val_loss: 0.0098 - val_mean_absolute_error: 0.0792
# Epoch 19/30
# 6869/6869 [==============================] - 1s 138us/sample - loss: 0.0106 - mean_absolute_error: 0.0821 - val_loss: 0.0099 - val_mean_absolute_error: 0.0796
# Epoch 20/30
# 6869/6869 [==============================] - 1s 137us/sample - loss: 0.0106 - mean_absolute_error: 0.0819 - val_loss: 0.0096 - val_mean_absolute_error: 0.0784
# Epoch 21/30
# 6869/6869 [==============================] - 1s 131us/sample - loss: 0.0102 - mean_absolute_error: 0.0807 - val_loss: 0.0093 - val_mean_absolute_error: 0.0771
# Epoch 22/30
# 6869/6869 [==============================] - 1s 127us/sample - loss: 0.0101 - mean_absolute_error: 0.0801 - val_loss: 0.0090 - val_mean_absolute_error: 0.0759
# Epoch 23/30
# 6869/6869 [==============================] - 1s 132us/sample - loss: 0.0098 - mean_absolute_error: 0.0791 - val_loss: 0.0090 - val_mean_absolute_error: 0.0759
# Epoch 24/30
# 6869/6869 [==============================] - 1s 133us/sample - loss: 0.0097 - mean_absolute_error: 0.0787 - val_loss: 0.0088 - val_mean_absolute_error: 0.0751
# Epoch 25/30
# 6869/6869 [==============================] - 1s 129us/sample - loss: 0.0096 - mean_absolute_error: 0.0783 - val_loss: 0.0088 - val_mean_absolute_error: 0.0749
# Epoch 26/30
# 6869/6869 [==============================] - 1s 133us/sample - loss: 0.0096 - mean_absolute_error: 0.0780 - val_loss: 0.0089 - val_mean_absolute_error: 0.0753
# Epoch 27/30
# 6869/6869 [==============================] - 1s 138us/sample - loss: 0.0093 - mean_absolute_error: 0.0771 - val_loss: 0.0086 - val_mean_absolute_error: 0.0742
# Epoch 28/30
# 6869/6869 [==============================] - 1s 130us/sample - loss: 0.0093 - mean_absolute_error: 0.0769 - val_loss: 0.0086 - val_mean_absolute_error: 0.0740
# Epoch 29/30
# 6869/6869 [==============================] - 1s 131us/sample - loss: 0.0092 - mean_absolute_error: 0.0767 - val_loss: 0.0088 - val_mean_absolute_error: 0.0748
# Epoch 30/30
# 6869/6869 [==============================] - 1s 129us/sample - loss: 0.0093 - mean_absolute_error: 0.0768 - val_loss: 0.0089 - val_mean_absolute_error: 0.0757
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          multiple                  0
# _________________________________________________________________
# dense_4 (Dense)              multiple                  1023500
# _________________________________________________________________
# dropout_3 (Dropout)          multiple                  0
# _________________________________________________________________
# dense_5 (Dense)              multiple                  32565
# =================================================================
# Total params: 1,056,065
# Trainable params: 1,056,065
# Non-trainable params: 0
# _________________________________________________________________
# 869/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %% [markdown]
# ## LSTM RNN model

# %%
def f_lstm_model(input_shape, output_shape):
    model = tf.keras.Sequential([
        
            tf.keras.layers.LSTM(units = 1000, input_shape = input_shape, kernel_initializer='random_normal', bias_initializer='zeros', dropout=0.2, return_sequences=True),
        
            tf.keras.layers.LSTM(units = 700, input_shape = input_shape, kernel_initializer='random_normal', bias_initializer='zeros', dropout=0.2, return_sequences=False),

            tf.keras.layers.Dense(output_shape)])
    return model

input_shape = train_data[0].shape
output_shape = train_target.shape[1]
lstm_model = f_lstm_model(input_shape, output_shape)

# %%
max_epochs = 30
batch_size = 50
lstm_history, lstm_prediction = compile_and_fit(lstm_model, train_data, train_target, val_data, val_target, 
                                                test_data, test_target, max_epochs, batch_size, test_entry, label_width)
# Out:
# Train on 6869 samples, validate on 1869 samples
# Epoch 1/30
# 6869/6869 [==============================] - 12s 2ms/sample - loss: 0.0314 - mean_absolute_error: 0.1332 - val_loss: 0.0249 - val_mean_absolute_error: 0.1270
# Epoch 2/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0234 - mean_absolute_error: 0.1216 - val_loss: 0.0249 - val_mean_absolute_error: 0.1269
# Epoch 3/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0233 - mean_absolute_error: 0.1213 - val_loss: 0.0248 - val_mean_absolute_error: 0.1266
# Epoch 4/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0232 - mean_absolute_error: 0.1210 - val_loss: 0.0247 - val_mean_absolute_error: 0.1264
# Epoch 5/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0231 - mean_absolute_error: 0.1206 - val_loss: 0.0244 - val_mean_absolute_error: 0.1256
# Epoch 6/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0225 - mean_absolute_error: 0.1192 - val_loss: 0.0238 - val_mean_absolute_error: 0.1248
# Epoch 7/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0219 - mean_absolute_error: 0.1176 - val_loss: 0.0229 - val_mean_absolute_error: 0.1222
# Epoch 8/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0208 - mean_absolute_error: 0.1150 - val_loss: 0.0220 - val_mean_absolute_error: 0.1198
# Epoch 9/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0198 - mean_absolute_error: 0.1123 - val_loss: 0.0211 - val_mean_absolute_error: 0.1169
# Epoch 10/30
# 6869/6869 [==============================] - 8s 1ms/sample - loss: 0.0184 - mean_absolute_error: 0.1079 - val_loss: 0.0185 - val_mean_absolute_error: 0.1093
# Epoch 11/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0159 - mean_absolute_error: 0.1003 - val_loss: 0.0155 - val_mean_absolute_error: 0.0997
# Epoch 12/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0138 - mean_absolute_error: 0.0933 - val_loss: 0.0136 - val_mean_absolute_error: 0.0932
# Epoch 13/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0101 - mean_absolute_error: 0.0798 - val_loss: 0.0093 - val_mean_absolute_error: 0.0779
# Epoch 14/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0077 - mean_absolute_error: 0.0697 - val_loss: 0.0073 - val_mean_absolute_error: 0.0688
# Epoch 15/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0068 - mean_absolute_error: 0.0653 - val_loss: 0.0070 - val_mean_absolute_error: 0.0672
# Epoch 16/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0055 - mean_absolute_error: 0.0588 - val_loss: 0.0076 - val_mean_absolute_error: 0.0698
# Epoch 17/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0063 - mean_absolute_error: 0.0622 - val_loss: 0.0051 - val_mean_absolute_error: 0.0572
# Epoch 18/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0044 - mean_absolute_error: 0.0525 - val_loss: 0.0048 - val_mean_absolute_error: 0.0551
# Epoch 19/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0041 - mean_absolute_error: 0.0507 - val_loss: 0.0047 - val_mean_absolute_error: 0.0544
# Epoch 20/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0038 - mean_absolute_error: 0.0487 - val_loss: 0.0046 - val_mean_absolute_error: 0.0539
# Epoch 21/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0036 - mean_absolute_error: 0.0477 - val_loss: 0.0045 - val_mean_absolute_error: 0.0537
# Epoch 22/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0035 - mean_absolute_error: 0.0469 - val_loss: 0.0046 - val_mean_absolute_error: 0.0538
# Epoch 23/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0034 - mean_absolute_error: 0.0460 - val_loss: 0.0045 - val_mean_absolute_error: 0.0537
# Epoch 24/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0033 - mean_absolute_error: 0.0456 - val_loss: 0.0046 - val_mean_absolute_error: 0.0541
# Epoch 25/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0032 - mean_absolute_error: 0.0450 - val_loss: 0.0046 - val_mean_absolute_error: 0.0541
# Epoch 26/30
# 6869/6869 [==============================] - 7s 1ms/sample - loss: 0.0032 - mean_absolute_error: 0.0447 - val_loss: 0.0046 - val_mean_absolute_error: 0.0542
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 66, 1000)          4128000
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 700)               4762800
# _________________________________________________________________
# dense_11 (Dense)             (None, 65)                45565
# =================================================================
# Total params: 8,936,365
# Trainable params: 8,936,365
# Non-trainable params: 0
# _________________________________________________________________
# 869/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...

# %% [markdown]
# ## GRU RNN model

# %%
def f_gru_model(input_shape, output_shape):
    model = tf.keras.Sequential([
        
        tf.keras.layers.GRU(units = 1000, input_shape = input_shape, kernel_initializer='random_normal', bias_initializer='zeros', dropout=0.2, return_sequences=True),
        
        tf.keras.layers.GRU(units = 700, input_shape = input_shape, kernel_initializer='random_normal', bias_initializer='zeros', dropout=0.2, return_sequences=False),

            tf.keras.layers.Dense(output_shape)])
    return model

input_shape = train_data[0].shape
output_shape = train_target.shape[1]
gru_model = f_gru_model(input_shape, output_shape)

# %%
max_epochs = 30
batch_size = 50
gru_history, gru_prediction = compile_and_fit(gru_model, train_data, train_target, val_data, val_target, 
                                              test_data, test_target, max_epochs, batch_size, test_entry, label_width)
# Out:
# Train on 6869 samples, validate on 1869 samples
# Epoch 1/30
# 6869/6869 [==============================] - 11s 2ms/sample - loss: 0.0355 - mean_absolute_error: 0.1422 - val_loss: 0.0252 - val_mean_absolute_error: 0.1278
# Epoch 2/30
# 6869/6869 [==============================] - 6s 921us/sample - loss: 0.0242 - mean_absolute_error: 0.1235 - val_loss: 0.0249 - val_mean_absolute_error: 0.1271
# Epoch 3/30
# 6869/6869 [==============================] - 6s 922us/sample - loss: 0.0234 - mean_absolute_error: 0.1214 - val_loss: 0.0239 - val_mean_absolute_error: 0.1247
# Epoch 4/30
# 6869/6869 [==============================] - 6s 918us/sample - loss: 0.0224 - mean_absolute_error: 0.1189 - val_loss: 0.0231 - val_mean_absolute_error: 0.1229
# Epoch 5/30
# 6869/6869 [==============================] - 6s 919us/sample - loss: 0.0215 - mean_absolute_error: 0.1167 - val_loss: 0.0223 - val_mean_absolute_error: 0.1208
# Epoch 6/30
# 6869/6869 [==============================] - 6s 921us/sample - loss: 0.0209 - mean_absolute_error: 0.1151 - val_loss: 0.0234 - val_mean_absolute_error: 0.1235
# Epoch 7/30
# 6869/6869 [==============================] - 6s 916us/sample - loss: 0.0206 - mean_absolute_error: 0.1144 - val_loss: 0.0266 - val_mean_absolute_error: 0.1322
# Epoch 8/30
# 6869/6869 [==============================] - 6s 922us/sample - loss: 0.0213 - mean_absolute_error: 0.1163 - val_loss: 0.0221 - val_mean_absolute_error: 0.1205
# Epoch 9/30
# 6869/6869 [==============================] - 6s 929us/sample - loss: 0.0180 - mean_absolute_error: 0.1069 - val_loss: 0.0177 - val_mean_absolute_error: 0.1077
# Epoch 10/30
# 6869/6869 [==============================] - 6s 917us/sample - loss: 0.0166 - mean_absolute_error: 0.1025 - val_loss: 0.0173 - val_mean_absolute_error: 0.1058
# Epoch 11/30
# 6869/6869 [==============================] - 6s 916us/sample - loss: 0.0154 - mean_absolute_error: 0.0986 - val_loss: 0.0150 - val_mean_absolute_error: 0.0987
# Epoch 12/30
# 6869/6869 [==============================] - 6s 916us/sample - loss: 0.0139 - mean_absolute_error: 0.0937 - val_loss: 0.0140 - val_mean_absolute_error: 0.0951
# Epoch 13/30
# 6869/6869 [==============================] - 6s 921us/sample - loss: 0.0125 - mean_absolute_error: 0.0891 - val_loss: 0.0113 - val_mean_absolute_error: 0.0854
# Epoch 14/30
# 6869/6869 [==============================] - 6s 913us/sample - loss: 0.0105 - mean_absolute_error: 0.0817 - val_loss: 0.0098 - val_mean_absolute_error: 0.0797
# Epoch 15/30
# 6869/6869 [==============================] - 6s 893us/sample - loss: 0.0093 - mean_absolute_error: 0.0768 - val_loss: 0.0087 - val_mean_absolute_error: 0.0749
# Epoch 16/30
# 6869/6869 [==============================] - 6s 899us/sample - loss: 0.0083 - mean_absolute_error: 0.0726 - val_loss: 0.0078 - val_mean_absolute_error: 0.0709
# Epoch 17/30
# 6869/6869 [==============================] - 6s 895us/sample - loss: 0.0075 - mean_absolute_error: 0.0689 - val_loss: 0.0069 - val_mean_absolute_error: 0.0666
# Epoch 18/30
# 6869/6869 [==============================] - 6s 895us/sample - loss: 0.0067 - mean_absolute_error: 0.0652 - val_loss: 0.0063 - val_mean_absolute_error: 0.0637
# Epoch 19/30
# 6869/6869 [==============================] - 6s 897us/sample - loss: 0.0062 - mean_absolute_error: 0.0625 - val_loss: 0.0058 - val_mean_absolute_error: 0.0611
# Epoch 20/30
# 6869/6869 [==============================] - 6s 896us/sample - loss: 0.0057 - mean_absolute_error: 0.0600 - val_loss: 0.0055 - val_mean_absolute_error: 0.0594
# Epoch 21/30
# 6869/6869 [==============================] - 6s 893us/sample - loss: 0.0053 - mean_absolute_error: 0.0578 - val_loss: 0.0052 - val_mean_absolute_error: 0.0576
# Epoch 22/30
# 6869/6869 [==============================] - 6s 895us/sample - loss: 0.0050 - mean_absolute_error: 0.0560 - val_loss: 0.0051 - val_mean_absolute_error: 0.0568
# Epoch 23/30
# 6869/6869 [==============================] - 6s 896us/sample - loss: 0.0047 - mean_absolute_error: 0.0547 - val_loss: 0.0049 - val_mean_absolute_error: 0.0561
# Epoch 24/30
# 6869/6869 [==============================] - 6s 893us/sample - loss: 0.0045 - mean_absolute_error: 0.0536 - val_loss: 0.0049 - val_mean_absolute_error: 0.0561
# Epoch 25/30
# 6869/6869 [==============================] - 6s 894us/sample - loss: 0.0044 - mean_absolute_error: 0.0526 - val_loss: 0.0047 - val_mean_absolute_error: 0.0549
# Epoch 26/30
# 6869/6869 [==============================] - 6s 896us/sample - loss: 0.0042 - mean_absolute_error: 0.0518 - val_loss: 0.0047 - val_mean_absolute_error: 0.0547
# Epoch 27/30
# 6869/6869 [==============================] - 6s 902us/sample - loss: 0.0041 - mean_absolute_error: 0.0510 - val_loss: 0.0047 - val_mean_absolute_error: 0.0544
# Epoch 28/30
# 6869/6869 [==============================] - 6s 900us/sample - loss: 0.0040 - mean_absolute_error: 0.0505 - val_loss: 0.0047 - val_mean_absolute_error: 0.0545
# Epoch 29/30
# 6869/6869 [==============================] - 6s 892us/sample - loss: 0.0039 - mean_absolute_error: 0.0499 - val_loss: 0.0047 - val_mean_absolute_error: 0.0544
# Epoch 30/30
# 6869/6869 [==============================] - 6s 894us/sample - loss: 0.0039 - mean_absolute_error: 0.0494 - val_loss: 0.0046 - val_mean_absolute_error: 0.0542
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_1 (GRU)                  (None, 66, 1000)          3099000
# _________________________________________________________________
# gru_2 (GRU)                  (None, 700)               3574200
# _________________________________________________________________
# dense_10 (Dense)             (None, 65)                45565
# =================================================================
# Total params: 6,718,765
# Trainable params: 6,718,765
# Non-trainable params: 0
# _________________________________________________________________
# 869/1 [========================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
